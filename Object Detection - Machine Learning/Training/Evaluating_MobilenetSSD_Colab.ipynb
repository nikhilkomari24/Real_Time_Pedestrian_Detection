# %% [markdown]
# # Notebook to Evaluate checkpoints of Trained model
#
# ---
# This notebook runs parallel with the training notebook. During training, Tensorflow's training pipeline creates checkpoints of model and stores in google drive. This notebook picks the latest checkpoint stored and evaluate it using 'coco_detection_metrics' provided by pycocotools package in python. Results are stored in specified directory and can be analysed using TensorBoard. This notebooks aids in deciding when to stop training.

# %% [markdown]
# # Importing Libraries

# %% [markdown]
# Downgrading to TensorFlow version 1.x to avoid any version conflicts

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# Importing TensorFlow

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
   raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
print(tf.__version__)
# Out:
# Found GPU at: /device:GPU:0
# 1.15.2

# %% [markdown]
# Mounting Google Drive with Colab and authenticating with google account

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ### Configure PYTHONPATH environment variable

# %%
import os
os.environ['PYTHONPATH'] += ':/content/gdrive/My Drive/Tensorflow1/models/research/:/content/gdrive/My Drive/Tensorflow1/models/research/slim'

# %% [markdown]
# # Installing Pycocotools

# %%
# %cd /content/gdrive/My Drive/Tensorflow1
# Out:
# /content/gdrive/My Drive/Tensorflow1

# %% [markdown]
# Clone pycocotools repository

# %%
# !git clone https://github.com/cocodataset/cocoapi.git

# %% [markdown]
# Build cocoapi api and move pycocotools to ../Tensorflow1/models/research/ path

# %%
# %cd cocoapi/PythonAPI

# %%
# !python setup.py build_ext --inplace

# %%
# %cp -r pycocotools ../Tensorflow1/models/research/

# %% [markdown]
# Installing the required dependencies

# %%
# !pip install --upgrade tf-slim
# Out:
# ...
#      |████████████████████████████████| 358kB 7.2MB/s
# ...

# %% [markdown]
# #Run the evaluation script
#
# provide path to checkpoint directory, path to *.config file and target directory to store the results.

# %%
# %cd /content/gdrive/My Drive/Tensorflow1/models/research/object_detection

# %%
# !python eval.py --logtostderr --pipeline_config_path=training/ssd_mobilenet_v2_coco.config --checkpoint_dir=training/ --eval_dir=eval
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/absl/app.py:250: main (from __main__) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use object_detection/model_main.py.
# W0703 05:24:03.418199 139881972434816 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/absl/app.py:250: main (from __main__) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use object_detection/model_main.py.
# WARNING:tensorflow:From /content/gdrive/My Drive/Tensorflow1/models/research/object_detection/builders/dataset_builder.py:101: parallel_interleave (from tensorflow.contrib.data.python.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.parallel_interleave(...)`.
# ...

# %% [markdown]
# # Load TensorBoard

# %%
# %load_ext tensorboard

# %%
tensorboard --logdir=eval
# Out:
#     <div id="root"></div>
#     <script>
#       (function() {
#         window.TENSORBOARD_ENV = window.TENSORBOARD_ENV || {};
#         window.TENSORBOARD_ENV["IN_COLAB"] = true;
#         document.querySelector("base").href = "https://localhost:6006";
#         function fixUpTensorboard(root) {
#           const tftb = root.querySelector("tf-tensorboard");
#           // Disable the fragment manipulation behavior in Colab. Not
#           // only is the behavior not useful (as the iframe's location
#           // is not visible to the user), it causes TensorBoard's usage
#           // of `window.replace` to navigate away from the page and to
#           // the `localhost:<port>` URL specified by the base URI, which
#           // in turn causes the frame to (likely) crash.
#           tftb.removeAttribute("use-hash");
#         }
#         function executeAllScripts(root) {
#           // When `script` elements are inserted into the DOM by
# ...
